# %% [markdown]
# <a href="https://colab.research.google.com/github/JorgeZarama/Supervisado/blob/main/3_1_3_var_cualitativas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Creación aleatoria de datos
import numpy as np
import random
random.seed(42)

# %%
nivel_estudios = []
nivel_estudios.extend(['Secundaria']*110)
nivel_estudios.extend(['Bachillerato']*172)
nivel_estudios.extend(['Grado']*145)
nivel_estudios.extend(['Master']*52)
nivel_estudios.extend(['Doctorado']*21)

nivel_estudios = np.random.permutation(nivel_estudios)

# %%
print(nivel_estudios)
# Out:
# ['Bachillerato' 'Bachillerato' 'Secundaria' 'Secundaria' 'Bachillerato'
#  'Bachillerato' 'Master' 'Grado' 'Master' 'Secundaria' 'Grado'
#  'Bachillerato' 'Master' 'Grado' 'Grado' 'Secundaria' 'Master' 'Grado'
#  'Secundaria' 'Bachillerato' 'Grado' 'Secundaria' 'Master' 'Secundaria'
#  'Doctorado' 'Bachillerato' 'Grado' 'Grado' 'Bachillerato' 'Grado'
#  'Secundaria' 'Bachillerato' 'Grado' 'Bachillerato' 'Grado' 'Grado'
#  'Bachillerato' 'Bachillerato' 'Bachillerato' 'Secundaria' 'Bachillerato'
#  'Grado' 'Bachillerato' 'Secundaria' 'Bachillerato' 'Secundaria' 'Grado'
#  'Secundaria' 'Bachillerato' 'Secundaria' 'Grado' 'Secundaria' 'Grado'
#  'Bachillerato' 'Bachillerato' 'Secundaria' 'Bachillerato' 'Bachillerato'
#  'Doctorado' 'Bachillerato' 'Bachillerato' 'Bachillerato' 'Secundaria'
#  'Secundaria' 'Secundaria' 'Bachillerato' 'Bachillerato' 'Secundaria'
#  'Grado' 'Bachillerato' 'Grado' 'Grado' 'Bachillerato' 'Grado' 'Grado'
#  'Bachillerato' 'Master' 'Grado' 'Secundaria' 'Doctorado' 'Bachillerato'
#  'Master' 'Bachillerato' 'Secundaria' 'Bachillerato' 'Bachillerato'
#  'Grado' 'Bachillerato' 'Grado' 'Secundaria' 'Master' 'Grado' 'Grado'
#  'Grado' 'Grado' 'Secundaria' 'Grado' 'Secundaria' 'Bachillerato' 'Grado'
#  'Master' 'Bachillerato' 'Grado' 'Master' 'Secundaria' 'Secundaria'
#  'Grado' 'Grado' 'Bachillerato' 'Grado' 'Bachillerato' 'Master' 'Master'
#  'Grado' 'Grado' 'Secundaria' 'Bachillerato' 'Doctorado' 'Secundaria'
#  'Grado' 'Secundaria' 'Bachillerato' 'Master' 'Grado' 'Master' 'Doctorado'
#  'Bachillerato' 'Doctorado' 'Grado' 'Grado' 'Secundaria' 'Secundaria'
#  'Secundaria' 'Grado' 'Grado' 'Grado' 'Grado' 'Grado' 'Grado' 'Master'
#  'Bachillerato' 'Bachillerato' 'Master' 'Master' 'Secundaria' 'Secundaria'
#  'Bachillerato' 'Secundaria' 'Grado' 'Bachillerato' 'Bachillerato'
#  'Secundaria' 'Grado' 'Doctorado' 'Secundaria' 'Grado' 'Doctorado'
#  'Secundaria' 'Secundaria' 'Secundaria' 'Secundaria' 'Grado'
#  'Bachillerato' 'Bachillerato' 'Doctorado' 'Doctorado' 'Grado'
#  'Bachillerato' 'Grado' 'Secundaria' 'Bachillerato' 'Master' 'Master'
#  'Bachillerato' 'Bachillerato' 'Master' 'Secundaria' 'Bachillerato'
#  'Bachillerato' 'Bachillerato' 'Grado' 'Bachillerato' 'Bachillerato'
#  'Grado' 'Secundaria' 'Bachillerato' 'Bachillerato' 'Secundaria'
#  'Bachillerato' 'Bachillerato' 'Grado' 'Secundaria' 'Secundaria'
#  'Bachillerato' 'Master' 'Grado' 'Grado' 'Bachillerato' 'Secundaria'
#  'Bachillerato' 'Bachillerato' 'Doctorado' 'Bachillerato' 'Secundaria'
#  'Secundaria' 'Master' 'Bachillerato' 'Secundaria' 'Master' 'Bachillerato'
#  'Grado' 'Grado' 'Grado' 'Bachillerato' 'Grado' 'Grado' 'Bachillerato'
#  'Secundaria' 'Bachillerato' 'Grado' 'Secundaria' 'Bachillerato'
#  'Secundaria' 'Secundaria' 'Master' 'Grado' 'Secundaria' 'Grado' 'Grado'
#  'Bachillerato' 'Bachillerato' 'Bachillerato' 'Bachillerato' 'Grado'
#  'Bachillerato' 'Bachillerato' 'Grado' 'Grado' 'Bachillerato'
#  'Bachillerato' 'Bachillerato' 'Bachillerato' 'Bachillerato' 'Doctorado'
#  'Bachillerato' 'Secundaria' 'Doctorado' 'Bachillerato' 'Grado' 'Grado'
#  'Bachillerato' 'Secundaria' 'Grado' 'Bachillerato' 'Grado' 'Grado'
#  'Grado' 'Master' 'Bachillerato' 'Bachillerato' 'Grado' 'Grado' 'Grado'
#  'Bachillerato' 'Bachillerato' 'Secundaria' 'Secundaria' 'Secundaria'
#  'Grado' 'Bachillerato' 'Bachillerato' 'Bachillerato' 'Secundaria'
#  'Bachillerato' 'Grado' 'Bachillerato' 'Bachillerato' 'Bachillerato'
#  'Secundaria' 'Grado' 'Secundaria' 'Grado' 'Master' 'Master'
#  'Bachillerato' 'Master' 'Secundaria' 'Grado' 'Master' 'Bachillerato'
#  'Grado' 'Doctorado' 'Grado' 'Bachillerato' 'Bachillerato' 'Master'
#  'Doctorado' 'Doctorado' 'Grado' 'Bachillerato' 'Bachillerato'
#  'Bachillerato' 'Bachillerato' 'Bachillerato' 'Bachillerato' 'Doctorado'
#  'Grado' 'Grado' 'Grado' 'Grado' 'Bachillerato' 'Secundaria'
#  'Bachillerato' 'Secundaria' 'Secundaria' 'Secundaria' 'Master'
#  'Bachillerato' 'Master' 'Bachillerato' 'Bachillerato' 'Bachillerato'
#  'Grado' 'Bachillerato' 'Secundaria' 'Grado' 'Bachillerato' 'Secundaria'
#  'Grado' 'Bachillerato' 'Bachillerato' 'Grado' 'Grado' 'Master' 'Master'
#  'Grado' 'Secundaria' 'Bachillerato' 'Grado' 'Master' 'Grado' 'Grado'
#  'Grado' 'Bachillerato' 'Secundaria' 'Bachillerato' 'Secundaria'
#  'Secundaria' 'Bachillerato' 'Secundaria' 'Grado' 'Bachillerato' 'Grado'
#  'Secundaria' 'Bachillerato' 'Grado' 'Bachillerato' 'Bachillerato'
#  'Secundaria' 'Master' 'Bachillerato' 'Secundaria' 'Master' 'Secundaria'
#  'Grado' 'Doctorado' 'Secundaria' 'Secundaria' 'Secundaria' 'Bachillerato'
#  'Secundaria' 'Secundaria' 'Secundaria' 'Bachillerato' 'Secundaria'
#  'Bachillerato' 'Bachillerato' 'Bachillerato' 'Master' 'Bachillerato'
#  'Grado' 'Master' 'Bachillerato' 'Master' 'Grado' 'Master' 'Secundaria'
#  'Grado' 'Bachillerato' 'Grado' 'Bachillerato' 'Bachillerato' 'Grado'
#  'Secundaria' 'Bachillerato' 'Bachillerato' 'Grado' 'Grado' 'Bachillerato'
#  'Bachillerato' 'Secundaria' 'Grado' 'Bachillerato' 'Bachillerato' 'Grado'
#  'Bachillerato' 'Grado' 'Grado' 'Grado' 'Secundaria' 'Secundaria'
#  'Bachillerato' 'Bachillerato' 'Secundaria' 'Grado' 'Grado' 'Master'
#  'Secundaria' 'Secundaria' 'Grado' 'Grado' 'Master' 'Master' 'Grado'
#  'Grado' 'Master' 'Bachillerato' 'Bachillerato' 'Master' 'Bachillerato'
#  'Grado' 'Secundaria' 'Bachillerato' 'Grado' 'Bachillerato' 'Bachillerato'
#  'Master' 'Secundaria' 'Doctorado' 'Bachillerato' 'Secundaria'
#  'Secundaria' 'Grado' 'Secundaria' 'Bachillerato' 'Secundaria' 'Grado'
#  'Bachillerato' 'Bachillerato' 'Bachillerato' 'Grado' 'Bachillerato'
#  'Grado' 'Secundaria' 'Bachillerato' 'Bachillerato' 'Master'
#  'Bachillerato' 'Bachillerato' 'Bachillerato' 'Secundaria' 'Master'
#  'Grado' 'Grado' 'Doctorado' 'Grado' 'Grado' 'Grado' 'Secundaria'
#  'Secundaria' 'Grado' 'Grado' 'Grado' 'Bachillerato' 'Master' 'Master'
#  'Master' 'Bachillerato' 'Grado' 'Secundaria' 'Grado' 'Grado' 'Doctorado'
#  'Secundaria' 'Grado' 'Bachillerato' 'Secundaria' 'Bachillerato'
#  'Bachillerato' 'Bachillerato' 'Grado' 'Grado' 'Bachillerato'
#  'Bachillerato' 'Grado' 'Grado' 'Bachillerato' 'Secundaria' 'Secundaria'
#  'Grado']

# %%
# DIAGRAMA DE BARRAS
import matplotlib.pyplot as plt
import numpy as np
estudios, frecuencia = np.unique(nivel_estudios, return_counts=True)
print(estudios, frecuencia)
# Out:
# ['Bachillerato' 'Doctorado' 'Grado' 'Master' 'Secundaria'] [172  21 145  52 110]

# %%
plt.ylabel('Frecuencia absoluta')
plt.xlabel('Nivel de estudios')
plt.title('Diagrama de barras')
plt.bar(estudios, frecuencia, color='orange', edgecolor='blue', linewidth=4) # https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.bar.html
plt.grid()
plt.show()

# %%
# DIAGRAMA DE SECTORES
colores = {'red', 'blue', 'orange', 'green', 'cyan'}
plt.pie(frecuencia, labels=estudios, colors=colores, autopct='%1.2f%%')
plt.title('Diagrama de sectores')
plt.show()
